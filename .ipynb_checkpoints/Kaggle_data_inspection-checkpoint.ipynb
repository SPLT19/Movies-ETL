# %%
import json
import pandas as pd 
import numpy as np

# %%
file_dir = 'C:/Users/splt1/Documents/GitHub/Movies-ETL/class/'

# %%
#to open the file using the extension,recommended after cleaning the data
f'{file_dir}wikipedia-movies.json'

# %%
#Explore (kagle data): import flat data from kaggle
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv')
ratings = pd.read_csv(f'{file_dir}ratings_small.csv')

# %%
#inspect metadata DataFrame
kaggle_metadata.head(5)

# %%
#inspect metadata DataFrame
kaggle_metadata.tail(5)

# %%
#inspect rating DataFrame
ratings.head(5)

# %%
#inspect rating DataFrame
ratings.tail(5)

# %%
#inspect rating DataFrame
ratings.sample(5)
